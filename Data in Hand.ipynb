# %% [markdown]
# <strong>Report Title:</strong> Final Project - Data in Hand <br>
# <strong>Name:</strong> Kendall Williams <br>
# <strong>Date:</strong> 11/16/25

# %% [raw]
# !conda install -y seaborn

# %%
import seaborn as sns

# %% [markdown]
# ### Barn Owl Data
# I have selected two CSV files from eBird data resource. This data shows the range of American Barn owls by region, continent, and season.

# %%
owls = pd.read_csv(r'\Users\kwill\Downloads\brnowl_regional_2023\brnowl_regional_2023.csv')
owls.head()
# Out:
#   species_code        common_name scientific_name  prediction_year  \
# 0       brnowl  American Barn Owl    Tyto furcata             2023
# 1       brnowl  American Barn Owl    Tyto furcata             2023
# 2       brnowl  American Barn Owl    Tyto furcata             2023
# 3       brnowl  American Barn Owl    Tyto furcata             2023
# 4       brnowl  American Barn Owl    Tyto furcata             2023
#
#   region_type region_code  region_name continent_code continent_name  \
# 0     country         ARG    Argentina             SA  South America
# 1     country         BHS  The Bahamas            NaN  North America
# 2     country         BLZ       Belize            NaN  North America
# 3     country         BMU      Bermuda            NaN  North America
# 4     country         BOL      Bolivia             SA  South America
#
#        season  start_date    end_date  abundance_mean  total_pop_percent  \
# ...

# %% [markdown]
# ### Forest Loss Data
# I selected another CSV file from Our World in Data's "Deforestation and Forest Loss" data report. This data shows the long term changes in forest cover globally.

# %%
url = "https://ourworldindata.org/grapher/annual-change-forest-area.csv?v=1&csvType=full&useColumnShortNames=true"
df = pd.read_csv(url)

# %%
df.head()[["Entity", "Year", "Code","Annual net change in forest area"]]
# Out:
#       Entity  Year Code  Annual net change in forest area
# 0    Algeria  1990  DZA                           -8800.0
# 1    Algeria  2000  DZA                           33900.0
# 2    Algeria  2010  DZA                            7600.0
# 3    Algeria  2015  DZA                           -1400.0
# 4  Argentina  1990  ARG                         -182600.0
